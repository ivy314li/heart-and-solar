# %%
from imutils.video import VideoStream
import argparse
import imutils
import time
import cv2
import sys
import numpy as np
import os
import utils

# %%
def camera_test():
    """used to locate all possible usb cameras on device"""
    all_camera_idx_available = []

    for camera_idx in range(-100, 900):
        cap = cv2.VideoCapture(camera_idx)
        if cap.isOpened():
            print(f'Camera index available: {camera_idx}')
            all_camera_idx_available.append(camera_idx)
            cap.release()

# %%
# Out:
# [INFO] starting video stream...

# %%
print("[INFO] starting video stream...")
vs = VideoStream(src=0).start()
time.sleep(2.0)
while True:
    time.sleep(1.0)
    frame = vs.read()

    image = imutils.resize(frame, width = 1000)
    #(corners, ids, rejected) = cv2.aruco.detectMarkers(image, arucoDict, parameters=arucoParams)
    output, rvecs, tvecs, corners, length, width = pose_estimation(image, arucoDict, mtx, dist)
    #cv2.imshow('rotate', output)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    tvec_list, rvec_list = clean_tvec_rvec(tvecs, rvecs)
    if len(tvec_list) != 5:
        print("[ERROR] not all markers were detected, trying again later")
        continue
    width, length = get_width_length(tvec_list)
    possible_points = calculate_possible_points(tvec_list, width, length)

    prediction = clean_points_and_vote(width, length, 2, possible_points)
    angle = diff_y_angle(rvec_list)
    print('location: ' + str(prediction))
    print('angle: ' + str(angle))
   
    
    if key == ord("q"):
        break
cv2.destroyAllWindows()
vs.stop()
# Out:
# [[[477. 303.]
#   [471. 430.]
#   [341. 434.]
#   [346. 300.]]]
# [INFO] ArUco marker ID: 3
# [[[475. 305.]
#   [473. 431.]
#   [343. 438.]
#   [344. 307.]]]
# [INFO] ArUco marker ID: 3
# [[[475. 305.]
#   [473. 431.]
#   [343. 438.]
#   [344. 307.]]]
# [INFO] ArUco marker ID: 3
# [[[475. 305.]
#   [473. 431.]
#   [343. 438.]
#   [344. 307.]]]
# [INFO] ArUco marker ID: 3
# [[[474. 304.]
#   [473. 431.]
#   [344. 437.]
#   [344. 306.]]]
# [INFO] ArUco marker ID: 3
# [[[474. 305.]
#   [473. 431.]
#   [344. 438.]
#   [344. 307.]]]
# [INFO] ArUco marker ID: 3
# [[[471. 307.]
#   [472. 432.]
#   [344. 440.]
#   [342. 312.]]]
# [INFO] ArUco marker ID: 3
# [[[469. 310.]
#   [471. 434.]
#   [344. 442.]
#   [340. 316.]]]
# [INFO] ArUco marker ID: 3
# [[[465. 171.]
#   [469. 295.]
#   [341. 300.]
#   [338. 172.]]]
# [INFO] ArUco marker ID: 2
# [[[469. 310.]
#   [471. 434.]
#   [344. 442.]
#   [340. 316.]]]
# [INFO] ArUco marker ID: 3
# [[[465. 171.]
#   [469. 295.]
#   [341. 300.]
# ...
